# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json
import os
from datetime import datetime
## Load the NASA_API_KEY from the env file
load_dotenv("example.env")
NASA_API_KEY = os.getenv('NASA_API_KEY')

if not NASA_API_KEY:
    print("NASA_API_KEY not found. Check your .env file.")
type(NASA_API_KEY)
# Out:
# str

# %% [markdown]
# ### CME Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for CMEs:
CME = "CME"

# Search for CMEs published between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for CME
cme_url = f"{base_url}{CME}?startDate={startDate}&endDate={endDate}&api_key={NASA_API_KEY}"
print(cme_url)
# Out:
# https://api.nasa.gov/DONKI/CME?startDate=2013-05-01&endDate=2024-05-01&api_key=OlCfwMMT3JoD00787nDzmWCs7meW9aiYQyAD9fMl

# %%
# Make a "GET" request for the CME URL and store it in a variable named cme_response
cme_response = requests.get(cme_url)

# %%
# Convert the response variable to json and store it as a variable named cme_json
cme_json = cme_response.json()

# %%
# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(cme_json[0], indent=4))
# Out:
# {
#     "activityID": "2013-05-01T03:12:00-CME-001",
#     "catalog": "M2M_CATALOG",
#     "startTime": "2013-05-01T03:12Z",
#     "instruments": [
#         {
#             "displayName": "SOHO: LASCO/C2"
#         },
#         {
#             "displayName": "SOHO: LASCO/C3"
#         },
#         {
#             "displayName": "STEREO A: SECCHI/COR2"
#         },
#         {
#             "displayName": "STEREO B: SECCHI/COR2"
#         }
#     ],
#     "sourceLocation": "",
#     "activeRegionNum": null,
#     "note": "",
#     "submissionTime": "2013-08-07T16:54Z",
#     "versionId": 1,
#     "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/CME/2349/-1",
#     "cmeAnalyses": [
#         {
#             "isMostAccurate": true,
#             "time21_5": "2013-05-01T07:07Z",
#             "latitude": 12.0,
#             "longitude": -120.0,
#             "halfAngle": 36.0,
#             "speed": 860.0,
#             "type": "C",
#             "featureCode": "null",
# ...

# %%
# Convert cme_json to a Pandas DataFrame 
cme_data = pd.DataFrame(cme_json)

# Keep only the columns: activityID, startTime, linkedEvents
cme_data = cme_data[['activityID', 'startTime', 'linkedEvents']]

cme_data.head()
# Out:
#                     activityID          startTime  \
# 0  2013-05-01T03:12:00-CME-001  2013-05-01T03:12Z
# 1  2013-05-02T05:24:00-CME-001  2013-05-02T05:24Z
# 2  2013-05-02T14:36:00-CME-001  2013-05-02T14:36Z
# 3  2013-05-03T18:00:00-CME-001  2013-05-03T18:00Z
# 4  2013-05-03T22:36:00-CME-001  2013-05-03T22:36Z
#
#                                       linkedEvents
# 0  [{'activityID': '2013-05-04T04:52:00-IPS-001'}]
# 1                                             None
# 2                                             None
# 3                                             None
# 4  [{'activityID': '2013-05-07T04:37:00-IPS-001'}]

# %%
# Notice that the linkedEvents column allows us to identify the corresponding GST
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to GSTs
cme_data = cme_data.dropna(subset=['linkedEvents'])

# Display the updated DataFrame
cme_data.head()
# Out:
#                      activityID          startTime  \
# 0   2013-05-01T03:12:00-CME-001  2013-05-01T03:12Z
# 4   2013-05-03T22:36:00-CME-001  2013-05-03T22:36Z
# 7   2013-05-09T19:29:00-CME-001  2013-05-09T19:29Z
# 10  2013-05-13T02:54:00-CME-001  2013-05-13T02:54Z
# 13  2013-05-13T16:18:00-CME-001  2013-05-13T16:18Z
#
#                                          linkedEvents
# 0     [{'activityID': '2013-05-04T04:52:00-IPS-001'}]
# 4     [{'activityID': '2013-05-07T04:37:00-IPS-001'}]
# 7     [{'activityID': '2013-05-12T23:30:00-IPS-001'}]
# 10  [{'activityID': '2013-05-13T01:53:00-FLR-001'}...
# 13  [{'activityID': '2013-05-13T15:40:00-FLR-001'}...

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Write a nested for loop that iterates first over each row in the cme DataFrame (using the index)
# and then iterates over the values in 'linkedEvents' 
# and adds the elements individually to a list of dictionaries where each row is one element 

# Initialize an empty list to store the expanded rows
expanded_rows = []

# Iterate over each index in the DataFrame
for index, row in cme_data.iterrows():
    # Iterate over each dictionary in the list
    for event in row['linkedEvents']:
        expanded_row = {
            'activityID': row['activityID'],
            'startTime': row['startTime'],
            'linkedEvents': event
        }
    
        # Append a new dictionary to the expanded_rows list for each dictionary item and corresponding 'activityID' and 'startTime' value
        expanded_rows.append(expanded_row)

# Create a new DataFrame from the expanded rows
expanded_cme_data = pd.DataFrame(expanded_rows)

# Display the new DataFrame
expanded_cme_data.head()
# Out:
#                     activityID          startTime  \
# 0  2013-05-01T03:12:00-CME-001  2013-05-01T03:12Z
# 1  2013-05-03T22:36:00-CME-001  2013-05-03T22:36Z
# 2  2013-05-09T19:29:00-CME-001  2013-05-09T19:29Z
# 3  2013-05-13T02:54:00-CME-001  2013-05-13T02:54Z
# 4  2013-05-13T02:54:00-CME-001  2013-05-13T02:54Z
#
#                                     linkedEvents
# 0  {'activityID': '2013-05-04T04:52:00-IPS-001'}
# 1  {'activityID': '2013-05-07T04:37:00-IPS-001'}
# 2  {'activityID': '2013-05-12T23:30:00-IPS-001'}
# 3  {'activityID': '2013-05-13T01:53:00-FLR-001'}
# 4  {'activityID': '2013-05-13T04:12:00-SEP-001'}

# %%
print(cme_data['linkedEvents'].iloc[0])
# Out:
# [{'activityID': '2013-05-04T04:52:00-IPS-001'}]

# %%
# Create a function called extract_activityID_from_dict that takes a dict as input such as in linkedEvents
def extract_activityID_from_dict(dict):
    try:
        return dict['activityID']
    except KeyError:
        print("There no element with 'activityID' key in your dictionary. Check your input.")
        # Log the error or print it for debugging


extract_activityID_from_dict(expanded_cme_data['linkedEvents'][0])
# Out:
# '2013-05-04T04:52:00-IPS-001'

# %%
# Apply this function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'GST_ActivityID' using loc indexer:
expanded_cme_data['GST_ActivityID'] = expanded_cme_data['linkedEvents'].apply(lambda x: extract_activityID_from_dict(x))

expanded_cme_data.head()
# Out:
#                     activityID          startTime  \
# 0  2013-05-01T03:12:00-CME-001  2013-05-01T03:12Z
# 1  2013-05-03T22:36:00-CME-001  2013-05-03T22:36Z
# 2  2013-05-09T19:29:00-CME-001  2013-05-09T19:29Z
# 3  2013-05-13T02:54:00-CME-001  2013-05-13T02:54Z
# 4  2013-05-13T02:54:00-CME-001  2013-05-13T02:54Z
#
#                                     linkedEvents               GST_ActivityID
# 0  {'activityID': '2013-05-04T04:52:00-IPS-001'}  2013-05-04T04:52:00-IPS-001
# 1  {'activityID': '2013-05-07T04:37:00-IPS-001'}  2013-05-07T04:37:00-IPS-001
# 2  {'activityID': '2013-05-12T23:30:00-IPS-001'}  2013-05-12T23:30:00-IPS-001
# 3  {'activityID': '2013-05-13T01:53:00-FLR-001'}  2013-05-13T01:53:00-FLR-001
# 4  {'activityID': '2013-05-13T04:12:00-SEP-001'}  2013-05-13T04:12:00-SEP-001

# %%
# Remove rows with missing GST_ActivityID, since we can't assign them to GSTs:
cleaned_cme_data = expanded_cme_data.dropna(subset=['GST_ActivityID'])

cleaned_cme_data.info()
cleaned_cme_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1714 entries, 0 to 1713
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   activityID      1714 non-null   object
#  1   startTime       1714 non-null   object
#  2   linkedEvents    1714 non-null   object
#  3   GST_ActivityID  1714 non-null   object
# dtypes: object(4)
# memory usage: 53.7+ KB
#                     activityID          startTime  \
# 0  2013-05-01T03:12:00-CME-001  2013-05-01T03:12Z
# 1  2013-05-03T22:36:00-CME-001  2013-05-03T22:36Z
# 2  2013-05-09T19:29:00-CME-001  2013-05-09T19:29Z
# 3  2013-05-13T02:54:00-CME-001  2013-05-13T02:54Z
# 4  2013-05-13T02:54:00-CME-001  2013-05-13T02:54Z
#
#                                     linkedEvents               GST_ActivityID
# 0  {'activityID': '2013-05-04T04:52:00-IPS-001'}  2013-05-04T04:52:00-IPS-001
# 1  {'activityID': '2013-05-07T04:37:00-IPS-001'}  2013-05-07T04:37:00-IPS-001
# ...

# %%
# print out the datatype of each column in this DataFrame:
cme_data.dtypes
# Out:
# activityID      object
# startTime       object
# linkedEvents    object
# dtype: object

# %%
# Convert the 'GST_ActivityID' column to string format 
expanded_cme_data['GST_ActivityID'] = expanded_cme_data['GST_ActivityID'].astype('string')

# Convert startTime to datetime format  
expanded_cme_data['startTime'] = pd.to_datetime(expanded_cme_data['startTime'])

# Rename startTime to startTime_CME and activityID to cmeID
expanded_cme_data = expanded_cme_data.rename(columns={'startTime': 'startTime_CME', 'activityID': 'cmeID'})

# Drop linkedEvents
clean_expanded_cme_data = expanded_cme_data.drop(columns=['linkedEvents'])

# Verify that all steps were executed correctly
clean_expanded_cme_data.dtypes
clean_expanded_cme_data.head()
# Out:
#                          cmeID             startTime_CME  \
# 0  2013-05-01T03:12:00-CME-001 2013-05-01 03:12:00+00:00
# 1  2013-05-03T22:36:00-CME-001 2013-05-03 22:36:00+00:00
# 2  2013-05-09T19:29:00-CME-001 2013-05-09 19:29:00+00:00
# 3  2013-05-13T02:54:00-CME-001 2013-05-13 02:54:00+00:00
# 4  2013-05-13T02:54:00-CME-001 2013-05-13 02:54:00+00:00
#
#                 GST_ActivityID
# 0  2013-05-04T04:52:00-IPS-001
# 1  2013-05-07T04:37:00-IPS-001
# 2  2013-05-12T23:30:00-IPS-001
# 3  2013-05-13T01:53:00-FLR-001
# 4  2013-05-13T04:12:00-SEP-001

# %%
# We are only interested in CMEs related to GSTs so keep only rows where the GST_ActivityID column contains 'GST'
# use the method 'contains()' from the str library.  
final_cme_df = clean_expanded_cme_data[clean_expanded_cme_data['GST_ActivityID'].str.contains('GST', na=False)]

final_cme_df.head()
# Out:
#                            cmeID             startTime_CME  \
# 21   2013-06-02T20:24:00-CME-001 2013-06-02 20:24:00+00:00
# 48   2013-09-29T22:40:00-CME-001 2013-09-29 22:40:00+00:00
# 90   2013-12-04T23:12:00-CME-001 2013-12-04 23:12:00+00:00
# 148  2014-02-16T14:15:00-CME-001 2014-02-16 14:15:00+00:00
# 151  2014-02-18T01:25:00-CME-001 2014-02-18 01:25:00+00:00
#
#                   GST_ActivityID
# 21   2013-06-07T03:00:00-GST-001
# 48   2013-10-02T03:00:00-GST-001
# 90   2013-12-08T00:00:00-GST-001
# 148  2014-02-19T03:00:00-GST-001
# 151  2014-02-20T03:00:00-GST-001

# %% [markdown]
# ### GST Data

# %%
# Set the base URL to NASA's DONKI API:
base_url = "https://api.nasa.gov/DONKI/"

# Set the specifier for Geomagnetic Storms (GST):
GST = "GST"

# Search for GSTs between a begin and end date
startDate = "2013-05-01"
endDate   = "2024-05-01"

# Build URL for GST
complete_gst_url = f"{base_url}{GST}?startDate={startDate}&endDate={endDate}&api_key={NASA_API_KEY}"

print(complete_gst_url)
# Out:
# https://api.nasa.gov/DONKI/GST?startDate=2013-05-01&endDate=2024-05-01&api_key=OlCfwMMT3JoD00787nDzmWCs7meW9aiYQyAD9fMl

# %%
# Make a "GET" request for the GST URL and store it in a variable named gst_response
gst_response = requests.get(complete_gst_url)

# %%
# Convert the response variable to json and store it as a variable named gst_json
gst_json = gst_response.json()

# Preview the first result in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(gst_json[0], indent=4))
# Out:
# {
#     "gstID": "2013-06-01T01:00:00-GST-001",
#     "startTime": "2013-06-01T01:00Z",
#     "allKpIndex": [
#         {
#             "observedTime": "2013-06-01T01:00Z",
#             "kpIndex": 6.0,
#             "source": "NOAA"
#         }
#     ],
#     "link": "https://webtools.ccmc.gsfc.nasa.gov/DONKI/view/GST/326/-1",
#     "linkedEvents": [
#         {
#             "activityID": "2013-05-31T15:45:00-HSS-001"
#         }
#     ],
#     "submissionTime": "2013-07-15T19:26Z",
#     "versionId": 1
# }

# %%
# Convert gst_json to a Pandas DataFrame
gst_data = pd.DataFrame(gst_json)

# Keep only the columns: gstID, startTime, linkedEvents
gst_data = gst_data[['gstID', 'startTime', 'linkedEvents']]

gst_data.head()
# Out:
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 2  2013-06-29T03:00:00-GST-001  2013-06-29T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-12-08T00:00:00-GST-001  2013-12-08T00:00Z
#
#                                         linkedEvents
# 0    [{'activityID': '2013-05-31T15:45:00-HSS-001'}]
# 1    [{'activityID': '2013-06-02T20:24:00-CME-001'}]
# 2                                               None
# 3  [{'activityID': '2013-09-29T22:40:00-CME-001'}...
# 4  [{'activityID': '2013-12-04T23:12:00-CME-001'}...

# %%
# Notice that the linkedEvents column allows us to identify the corresponding CME
# Remove rows with missing 'linkedEvents' since we won't be able to assign these to CME
gst_data = gst_data.dropna(subset='linkedEvents')

gst_data.info()
gst_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 105 entries, 0 to 116
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gstID         105 non-null    object
#  1   startTime     105 non-null    object
#  2   linkedEvents  105 non-null    object
# dtypes: object(3)
# memory usage: 3.3+ KB
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-12-08T00:00:00-GST-001  2013-12-08T00:00Z
# 5  2014-02-19T03:00:00-GST-001  2014-02-19T03:00Z
#
#                                         linkedEvents
# 0    [{'activityID': '2013-05-31T15:45:00-HSS-001'}]
# 1    [{'activityID': '2013-06-02T20:24:00-CME-001'}]
# 3  [{'activityID': '2013-09-29T22:40:00-CME-001'}...
# 4  [{'activityID': '2013-12-04T23:12:00-CME-001'}...
# ...

# %%
# Notice that the linkedEvents sometimes contains multiple events per row
# Use the explode method to ensure that each row is one element. Ensure to reset the index and drop missing values.
cleaned_gst_df = gst_data.explode('linkedEvents')
cleaned_gst_df.reset_index
cleaned_gst_df.info()
cleaned_gst_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 0 to 116
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   gstID         205 non-null    object
#  1   startTime     205 non-null    object
#  2   linkedEvents  205 non-null    object
# dtypes: object(3)
# memory usage: 6.4+ KB
#                          gstID          startTime  \
# 0  2013-06-01T01:00:00-GST-001  2013-06-01T01:00Z
# 1  2013-06-07T03:00:00-GST-001  2013-06-07T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 3  2013-10-02T03:00:00-GST-001  2013-10-02T03:00Z
# 4  2013-12-08T00:00:00-GST-001  2013-12-08T00:00Z
# 4  2013-12-08T00:00:00-GST-001  2013-12-08T00:00Z
# 5  2014-02-19T03:00:00-GST-001  2014-02-19T03:00Z
# 5  2014-02-19T03:00:00-GST-001  2014-02-19T03:00Z
# 6  2014-02-20T03:00:00-GST-001  2014-02-20T03:00Z
#
#                                     linkedEvents
# ...

# %%
# Apply the extract_activityID_from_dict function to each row in the 'linkedEvents' column (you can use apply() and a lambda function)
# and create a new column called 'CME_ActivityID' using loc indexer:

cleaned_gst_df['CME_ActivityID'] = cleaned_gst_df['linkedEvents'].apply(extract_activityID_from_dict)


# Remove rows with missing CME_ActivityID, since we can't assign them to CMEs:
cleaned_gst_df = cleaned_gst_df.dropna(subset='CME_ActivityID')

# %%
# Convert the 'CME_ActivityID' column to string format 
cleaned_gst_df['CME_ActivityID'] = cleaned_gst_df['CME_ActivityID'].astype('string')

# Convert the 'gstID' column to string format 
cleaned_gst_df['gstID'] = cleaned_gst_df['gstID'].astype('string')




# # Convert startTime to datetime format
cleaned_gst_df['startTime'] = pd.to_datetime(cleaned_gst_df['startTime'])

# # Rename startTime to startTime_GST 
cleaned_gst_df.rename(columns={'startTime':'startTime_GST'})

# # Drop linkedEvents
cleaned_gst_df = cleaned_gst_df.drop('linkedEvents', axis=1)

# # Verify that all steps were executed correctly
cleaned_gst_df.info()
cleaned_gst_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205 entries, 0 to 116
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gstID           205 non-null    string
#  1   startTime       205 non-null    datetime64[ns, UTC]
#  2   CME_ActivityID  205 non-null    string
# dtypes: datetime64[ns, UTC](1), string(2)
# memory usage: 6.4 KB
#                          gstID                 startTime  \
# 0  2013-06-01T01:00:00-GST-001 2013-06-01 01:00:00+00:00
# 1  2013-06-07T03:00:00-GST-001 2013-06-07 03:00:00+00:00
# 3  2013-10-02T03:00:00-GST-001 2013-10-02 03:00:00+00:00
# 3  2013-10-02T03:00:00-GST-001 2013-10-02 03:00:00+00:00
# 3  2013-10-02T03:00:00-GST-001 2013-10-02 03:00:00+00:00
#
#                 CME_ActivityID
# 0  2013-05-31T15:45:00-HSS-001
# 1  2013-06-02T20:24:00-CME-001
# 3  2013-09-29T22:40:00-CME-001
# 3  2013-10-02T01:54:00-IPS-001
# 3  2013-10-02T02:47:00-MPC-001

# %%
# We are only interested in GSTs related to CMEs so keep only rows where the CME_ActivityID column contains 'CME'
# use the method 'contains()' from the str library.  
final_gst_df = cleaned_gst_df.loc[cleaned_gst_df['CME_ActivityID'].str.contains('CME', case=True)]
final_gst_df.head()
# Out:
#                          gstID                 startTime  \
# 1  2013-06-07T03:00:00-GST-001 2013-06-07 03:00:00+00:00
# 3  2013-10-02T03:00:00-GST-001 2013-10-02 03:00:00+00:00
# 4  2013-12-08T00:00:00-GST-001 2013-12-08 00:00:00+00:00
# 5  2014-02-19T03:00:00-GST-001 2014-02-19 03:00:00+00:00
# 6  2014-02-20T03:00:00-GST-001 2014-02-20 03:00:00+00:00
#
#                 CME_ActivityID
# 1  2013-06-02T20:24:00-CME-001
# 3  2013-09-29T22:40:00-CME-001
# 4  2013-12-04T23:12:00-CME-001
# 5  2014-02-16T14:15:00-CME-001
# 6  2014-02-18T01:25:00-CME-001

# %% [markdown]
# ### Merge both datatsets

# %%
# Now merge both datasets using 'gstID' and 'CME_ActivityID' for gst and 'GST_ActivityID' and 'cmeID' for cme. Use the 'left_on' and 'right_on' specifiers.
merged_df = final_gst_df.merge(final_cme_df,left_on=['gstID','CME_ActivityID'], right_on=['GST_ActivityID','cmeID'], how='inner')
merged_df
# Out:
#                           gstID                 startTime  \
# 0   2013-06-07T03:00:00-GST-001 2013-06-07 03:00:00+00:00
# 1   2013-10-02T03:00:00-GST-001 2013-10-02 03:00:00+00:00
# 2   2013-12-08T00:00:00-GST-001 2013-12-08 00:00:00+00:00
# 3   2014-02-19T03:00:00-GST-001 2014-02-19 03:00:00+00:00
# 4   2014-02-20T03:00:00-GST-001 2014-02-20 03:00:00+00:00
# ..                          ...                       ...
# 56  2023-12-18T06:00:00-GST-001 2023-12-18 06:00:00+00:00
# 57  2024-03-03T18:00:00-GST-001 2024-03-03 18:00:00+00:00
# 58  2024-03-24T12:00:00-GST-001 2024-03-24 12:00:00+00:00
# 59  2024-03-24T12:00:00-GST-001 2024-03-24 12:00:00+00:00
# 60  2024-04-19T18:00:00-GST-001 2024-04-19 18:00:00+00:00
#
#                  CME_ActivityID                        cmeID  \
# 0   2013-06-02T20:24:00-CME-001  2013-06-02T20:24:00-CME-001
# 1   2013-09-29T22:40:00-CME-001  2013-09-29T22:40:00-CME-001
# 2   2013-12-04T23:12:00-CME-001  2013-12-04T23:12:00-CME-001
# ...

# %%
# Verify that the new DataFrame has the same number of rows as cme and gst
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gstID           61 non-null     string
#  1   startTime       61 non-null     datetime64[ns, UTC]
#  2   CME_ActivityID  61 non-null     object
#  3   cmeID           61 non-null     object
#  4   startTime_CME   61 non-null     datetime64[ns, UTC]
#  5   GST_ActivityID  61 non-null     string
# dtypes: datetime64[ns, UTC](2), object(2), string(2)
# memory usage: 3.0+ KB

# %% [markdown]
# ### Computing the time it takes for a CME to cause a GST

# %%
# Compute the time diff between startTime_GST and startTime_CME by creating a new column called `timeDiff`.
merged_df['timeDiff'] = merged_df['startTime'] - merged_df['startTime_CME']
merged_df.head()
# Out:
#                          gstID                 startTime  \
# 0  2013-06-07T03:00:00-GST-001 2013-06-07 03:00:00+00:00
# 1  2013-10-02T03:00:00-GST-001 2013-10-02 03:00:00+00:00
# 2  2013-12-08T00:00:00-GST-001 2013-12-08 00:00:00+00:00
# 3  2014-02-19T03:00:00-GST-001 2014-02-19 03:00:00+00:00
# 4  2014-02-20T03:00:00-GST-001 2014-02-20 03:00:00+00:00
#
#                 CME_ActivityID                        cmeID  \
# 0  2013-06-02T20:24:00-CME-001  2013-06-02T20:24:00-CME-001
# 1  2013-09-29T22:40:00-CME-001  2013-09-29T22:40:00-CME-001
# 2  2013-12-04T23:12:00-CME-001  2013-12-04T23:12:00-CME-001
# 3  2014-02-16T14:15:00-CME-001  2014-02-16T14:15:00-CME-001
# 4  2014-02-18T01:25:00-CME-001  2014-02-18T01:25:00-CME-001
#
#               startTime_CME               GST_ActivityID        timeDiff
# 0 2013-06-02 20:24:00+00:00  2013-06-07T03:00:00-GST-001 4 days 06:36:00
# 1 2013-09-29 22:40:00+00:00  2013-10-02T03:00:00-GST-001 2 days 04:20:00
# ...

# %%
# Use describe() to compute the mean and median time 
# that it takes for a CME to cause a GST. 
merged_df.describe()
# Out:
#                         timeDiff
# count                         61
# mean   2 days 23:29:26.557377049
# std    0 days 23:53:09.336914240
# min              1 days 08:36:00
# 25%              2 days 04:00:00
# 50%              2 days 19:51:00
# 75%              3 days 13:35:00
# max              6 days 03:00:00

# %% [markdown]
# ### Exporting data in csv format

# %%
# Export data to CSV without the index
merged_df.to_csv('Time_Data.csv', index=False)
